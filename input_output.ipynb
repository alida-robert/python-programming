# %% [markdown]
# # input output fn

# %%
name=input("enter your name:")
print(name)
# Out:
# anna

# %%
age=int(input("enter age"))
print(age)
# Out:
# 23

# %%
height=float(input("enter your height:"))
print(height)
# Out:
# 121.33

# %%
is_student=bool(input("Are you a student:"))
print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
city=input("which city do you live in ?")
print("you live in",city)
# Out:
# you live in chennai

# %%
company_name=input("Enter company name:")
company_location=input("Enter company location:")
Experience=int(input("Enter your experience:"))
salary=int(input("enter your salary:"))
print(" I am working in",company_name,"located at",company_location," I have",Experience,"year of experience.","My salary is",salary)
print("I am working in {} located at {} .I have {} year of experience.My salary is {}".format(company_name,company_location,Experience,salary))
print(f"I am working in {company_name} located at {company_location} .I have {Experience} year of experience.My salary is {salary}")
# Out:
#  I am working in sos located at calicut  I have 2 year of experience. My salary is 20000
# I am working in sos located at calicut .I have 2 year of experience.My salary is 20000
# I am working in sos located at calicut .I have 2 year of experience.My salary is 20000

# %% [markdown]
# # f-string

# %%
name1="anna"
marks=100
print(f"{name1} scored {marks} marks")
# Out:
# anna scored 100 marks

# %%
python_mark=int(input("enter mark"))
sql_mark=int(input("enter mark"))
excel_mark=int(input("enter mark"))
total_mark=python_mark+sql_mark+excel_mark
avg=total_mark/3
print(f"Your total mark is {total_mark} and  average mark is {avg} ")
# Out:
# Your total mark is 232 and  average mark is 77.33333333333333
